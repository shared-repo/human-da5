# %%
# !pip list | findstr beautifulsoup
# Out:
# beautifulsoup4            4.13.3

# %%
from urllib import request
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("http://developers.google.com")
html = response.content.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %%
print( soup.prettify() ) # 객체 트리를 사용해서 html 문자열을 재작성
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="721724668570-nbkv1cfusk7kk4eni4pjvepaus73b13t.apps.googleusercontent.com" name="google-signin-client-id"/>
#   <meta content="profile email https://www.googleapis.com/auth/developerprofiles https://www.googleapis.com/auth/developerprofiles.award" name="google-signin-scope"/>
#   <meta content="Google for Developers" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="#fff" name="theme-color"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="use-credentials" href="/_pwa/developers/manifest.json" rel="manifest"/>
#   <link crossorigin="" href="//www.gstatic.com" rel="preconnect"/>
#   <link crossorigin="" href="//fonts.gstatic.com" rel="preconnect"/>
#   <link crossorigin="" href="//fonts.googleapis.com" rel="preconnect"/>
# ...

# %%
print( type( soup.title ), soup.title )
print( soup.title.name, soup.title.text )
print( soup.title.parent.name )
print( soup.p )
# Out:
# <class 'bs4.element.Tag'> <title>Google for Developers - from AI and Cloud to Mobile and Web</title>
# title Google for Developers - from AI and Cloud to Mobile and Web
# link
# <p>Join us May 20-21 for live streamed keynotes, sessions, and more.</p>

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and
their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a>
and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>"""

soup = BeautifulSoup(html_doc, "html.parser")

# %%
print( type( soup.title ), soup.title )
print( soup.title.name, soup.title.text )
print( soup.title.parent.name )
print( soup.p )
# Out:
# <class 'bs4.element.Tag'> <title>The Dormouse's story</title>
# title The Dormouse's story
# head
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
for link in soup.find_all('a'):
    print(link.get('href'), link.get_text()) # get : 속성 읽기, get_text() : 내용 읽기
# Out:
# http://example.com/elsie Elsie
# http://example.com/lacie Lacie
# http://example.com/tillie Tillie

# %%
soup.select("#link2") # id="link2"인 태그 찾기
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]
