# %%
import urllib
# from urllib import request
import requests

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
api_key = "R+BEwJ49XVmTutdoCAdNq4m7wjOsdFNhVtlzkxWVeZJPhwQqWbGcD7CNeQPipFzIWAanQVw/rPLsGkfcYvD4AQ=="

url = "http://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade"

params ={
    'serviceKey' : api_key, 
    'LAWD_CD' : '11560', 
    'DEAL_YMD' : '202502', 
    'pageNo': '1',
    'numOfRows' : '100',
}

response = requests.get(url, params=params)
rescode = response.status_code # 응답 코드 읽기
if(rescode==200): # 200 : 정상응답
    print(response.content.decode('utf-8'))
    xml_str = response.content.decode('utf-8')
else:
    print("Error Code:" + str(rescode))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="yes"?><response><header><resultCode>000</resultCode><resultMsg>OK</resultMsg></header><body><items><item><aptDong> </aptDong><aptNm>현대3차</aptNm><buildYear>1997</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>57,300</dealAmount><dealDay>16</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 영등포구</estateAgentSggNm><excluUseAr>43.92</excluUseAr><floor>12</floor><jibun>608-1</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>대림동</umdNm></item><item><aptDong> </aptDong><aptNm>당산푸르지오</aptNm><buildYear>2004</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>104,500</dealAmount><dealDay>22</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 영등포구</estateAgentSggNm><excluUseAr>59.7</excluUseAr><floor>1</floor><jibun>91</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>영등포동8가</umdNm></item><item><aptDong> </aptDong><aptNm>삼성래미안</aptNm><buildYear>2001</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>72,500</dealAmount><dealDay>26</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 영등포구</estateAgentSggNm><excluUseAr>59.33</excluUseAr><floor>3</floor><jibun>4934</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>신길동</umdNm></item><item><aptDong> </aptDong><aptNm>삼환</aptNm><buildYear>1997</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>87,000</dealAmount><dealDay>25</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 영등포구</estateAgentSggNm><excluUseAr>59.53</excluUseAr><floor>18</floor><jibun>897-1</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>신길동</umdNm></item><item><aptDong> </aptDong><aptNm>e편한세상영등포아델포레</aptNm><buildYear>2020</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>120,000</dealAmount><dealDay>27</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 구로구</estateAgentSggNm><excluUseAr>84.9571</excluUseAr><floor>15</floor><jibun>1127</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>대림동</umdNm></item><item><aptDong> </aptDong><aptNm>삼환</aptNm><buildYear>1997</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>98,000</dealAmount><dealDay>22</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 영등포구</estateAgentSggNm><excluUseAr>84.83</excluUseAr><floor>15</floor><jibun>897-1</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>신길동</umdNm></item><item><aptDong> </aptDong><aptNm>현대3차</aptNm><buildYear>1997</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>79,000</dealAmount><dealDay>28</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 영등포구</estateAgentSggNm><excluUseAr>63.48</excluUseAr><floor>15</floor><jibun>608-1</jibun><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><sggCd>11560</sggCd><slerGbn>개인</slerGbn><umdNm>대림동</umdNm></item><item><aptDong> </aptDong><aptNm>양평현대6차</aptNm><buildYear>2000</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>93,000</dealAmount><dealDay>21</dealDay><dealMonth>2</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm> ...

# %%
from xml.etree import ElementTree as ET # XML을 처리하는 파이썬 모듈 (XML 파서)

# %%
parsed_xml = ET.fromstring(xml_str) # XML 문자열을 처리해서 객체의 트리를 만드는 함수

# %%
parsed_xml # <response> elemement 객체
# Out:
# <Element 'response' at 0x000001A6C60DBCE0>

# %%
print( parsed_xml.find("header") )
print( parsed_xml.find('body') )
body = parsed_xml.find('body')
# Out:
# <Element 'header' at 0x000001A6C60DB560>
# <Element 'body' at 0x000001A6C60DB5B0>

# %%
items = body.find('items')
items
# Out:
# <Element 'items' at 0x000001A6C60D83B0>

# %%
item_list = items.findall('item')
len( item_list ), item_list[0]
# Out:
# (100, <Element 'item' at 0x000001A6C60DBF10>)

# %%
for item in item_list:
    for child in item: # item 하위의 요소들을 순회
        print(child.tag, child.text)
    break
# Out:
# aptDong
# aptNm 현대3차
# buildYear 1997
# buyerGbn 개인
# cdealDay
# cdealType
# dealAmount 57,300
# dealDay 16
# dealMonth 2
# dealYear 2025
# dealingGbn 중개거래
# estateAgentSggNm 서울 영등포구
# excluUseAr 43.92
# floor 12
# jibun 608-1
# landLeaseholdGbn N
# rgstDate
# sggCd 11560
# slerGbn 개인
# umdNm 대림동
